# %%
# -*- coding: utf-8 -*-
# @Author: harshit
# @Date:   2019-05-14 07:03:11
# @Last Modified by:   harshit
# @Last Modified time: 2019-05-14 08:02:59

from keras.layers import Dense, Input
from keras.models import Model
from keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 1024
epochs = 10
sessions = 5

def sin():
    inputs = Input((1,))
    l0 = Dense(512, activation='relu', kernel_initializer="random_uniform")(inputs)
    l1 = Dense(1024, activation='relu', kernel_initializer="random_uniform")(l0)
    l2 = Dense(1024, activation='relu', kernel_initializer="random_uniform")(l1)
    output = Dense(1, activation='linear')(l2)

    model = Model(inputs=[inputs], outputs=[output])
    adm = Adam(lr=0.001)
    model.compile(optimizer=adm, loss='mean_absolute_error', metrics=['mae'])
    model.summary()
    return model

# %%
def main():
    model = sin()

    for sess in range(sessions):
        
        # Generate negative and positive X values
        # Calculate the Y matrix
        X = np.random.random_sample((batch_size,)) * 10 * np.pi - (5 * np.pi)
        Y = np.sin(X)
        
        for epoch in range(epochs):
            print("Epoch", epoch)
            model.fit(X, Y, validation_split=0.1)
            y_ = model.predict(X)

            fig, axs = plt.subplots(1, 2)
            axs[0].scatter(X, Y, color="blue")
            axs[1].scatter(X, y_, color="red")
            name = "session_" + str(sess) + "_epoch_" + str(epoch) + ".png"
            fig.savefig(os.path.join("./sinx_graphs", name))
            plt.close()

if __name__ == '__main__':
    main()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               1024
# _________________________________________________________________
# dense_26 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dense_27 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 1,576,961
# Trainable params: 1,576,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 0
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.6578 - mean_absolute_error: 0.6578 - val_loss: 0.6718 - val_mean_absolute_error: 0.6718
# Epoch 1
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.6180 - mean_absolute_error: 0.6180 - val_loss: 0.6610 - val_mean_absolute_error: 0.6610
# Epoch 2
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.5674 - mean_absolute_error: 0.5674 - val_loss: 0.6126 - val_mean_absolute_error: 0.6126
# Epoch 3
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.5175 - mean_absolute_error: 0.5175 - val_loss: 0.5869 - val_mean_absolute_error: 0.5869
# Epoch 4
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.5040 - mean_absolute_error: 0.5040 - val_loss: 0.5722 - val_mean_absolute_error: 0.5722
# Epoch 5
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.4870 - mean_absolute_error: 0.4870 - val_loss: 0.5455 - val_mean_absolute_error: 0.5455
# Epoch 6
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.4810 - mean_absolute_error: 0.4810 - val_loss: 0.5932 - val_mean_absolute_error: 0.5932
# Epoch 7
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.4550 - mean_absolute_error: 0.4550 - val_loss: 0.5196 - val_mean_absolute_error: 0.5196
# Epoch 8
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.4355 - mean_absolute_error: 0.4355 - val_loss: 0.4780 - val_mean_absolute_error: 0.4780
# Epoch 9
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.4229 - mean_absolute_error: 0.4229 - val_loss: 0.5031 - val_mean_absolute_error: 0.5031
# Epoch 0
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.4140 - mean_absolute_error: 0.4140 - val_loss: 0.3451 - val_mean_absolute_error: 0.3451
# Epoch 1
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.4166 - mean_absolute_error: 0.4166 - val_loss: 0.3636 - val_mean_absolute_error: 0.3636
# Epoch 2
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.4071 - mean_absolute_error: 0.4071 - val_loss: 0.3635 - val_mean_absolute_error: 0.3635
# Epoch 3
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.3893 - mean_absolute_error: 0.3893 - val_loss: 0.3451 - val_mean_absolute_error: 0.3451
# Epoch 4
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.3992 - mean_absolute_error: 0.3992 - val_loss: 0.3570 - val_mean_absolute_error: 0.3570
# Epoch 5
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.3938 - mean_absolute_error: 0.3938 - val_loss: 0.3568 - val_mean_absolute_error: 0.3568
# Epoch 6
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.3818 - mean_absolute_error: 0.3818 - val_loss: 0.3289 - val_mean_absolute_error: 0.3289
# Epoch 7
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.3706 - mean_absolute_error: 0.3706 - val_loss: 0.3295 - val_mean_absolute_error: 0.3295
# Epoch 8
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.3655 - mean_absolute_error: 0.3655 - val_loss: 0.3300 - val_mean_absolute_error: 0.3300
# Epoch 9
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 1ms/step - loss: 0.3631 - mean_absolute_error: 0.3631 - val_loss: 0.3057 - val_mean_absolute_error: 0.3057
# Epoch 0
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 1ms/step - loss: 0.3655 - mean_absolute_error: 0.3655 - val_loss: 0.3794 - val_mean_absolute_error: 0.3794
# Epoch 1
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.3558 - mean_absolute_error: 0.3558 - val_loss: 0.3772 - val_mean_absolute_error: 0.3772
# Epoch 2
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 1ms/step - loss: 0.3639 - mean_absolute_error: 0.3639 - val_loss: 0.3549 - val_mean_absolute_error: 0.3549
# Epoch 3
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.3509 - mean_absolute_error: 0.3509 - val_loss: 0.3579 - val_mean_absolute_error: 0.3579
# Epoch 4
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.3627 - mean_absolute_error: 0.3627 - val_loss: 0.3563 - val_mean_absolute_error: 0.3563
# Epoch 5
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 1s 2ms/step - loss: 0.3322 - mean_absolute_error: 0.3322 - val_loss: 0.3832 - val_mean_absolute_error: 0.3832
# Epoch 6
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.3398 - mean_absolute_error: 0.3398 - val_loss: 0.3727 - val_mean_absolute_error: 0.3727
# Epoch 7
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.3406 - mean_absolute_error: 0.3406 - val_loss: 0.3587 - val_mean_absolute_error: 0.3587
# Epoch 8
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.3420 - mean_absolute_error: 0.3420 - val_loss: 0.3446 - val_mean_absolute_error: 0.3446
# Epoch 9
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 5ms/step - loss: 0.3251 - mean_absolute_error: 0.3251 - val_loss: 0.2955 - val_mean_absolute_error: 0.2955
# Epoch 0
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 5s 5ms/step - loss: 0.2988 - mean_absolute_error: 0.2988 - val_loss: 0.3536 - val_mean_absolute_error: 0.3536
# Epoch 1
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.3099 - mean_absolute_error: 0.3099 - val_loss: 0.3615 - val_mean_absolute_error: 0.3615
# Epoch 2
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.2801 - mean_absolute_error: 0.2801 - val_loss: 0.3337 - val_mean_absolute_error: 0.3337
# Epoch 3
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.2708 - mean_absolute_error: 0.2708 - val_loss: 0.3025 - val_mean_absolute_error: 0.3025
# Epoch 4
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.2855 - mean_absolute_error: 0.2855 - val_loss: 0.3668 - val_mean_absolute_error: 0.3668
# Epoch 5
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.2790 - mean_absolute_error: 0.2790 - val_loss: 0.3469 - val_mean_absolute_error: 0.3469
# Epoch 6
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.2942 - mean_absolute_error: 0.2942 - val_loss: 0.2549 - val_mean_absolute_error: 0.2549
# Epoch 7
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.2443 - mean_absolute_error: 0.2443 - val_loss: 0.2289 - val_mean_absolute_error: 0.2289
# Epoch 8
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.2573 - mean_absolute_error: 0.2573 - val_loss: 0.2420 - val_mean_absolute_error: 0.2420
# Epoch 9
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.2481 - mean_absolute_error: 0.2481 - val_loss: 0.2196 - val_mean_absolute_error: 0.2196
# Epoch 0
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 3ms/step - loss: 0.2167 - mean_absolute_error: 0.2167 - val_loss: 0.2119 - val_mean_absolute_error: 0.2119
# Epoch 1
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.2457 - mean_absolute_error: 0.2457 - val_loss: 0.2845 - val_mean_absolute_error: 0.2845
# Epoch 2
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.2437 - mean_absolute_error: 0.2437 - val_loss: 0.2017 - val_mean_absolute_error: 0.2017
# Epoch 3
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.1820 - mean_absolute_error: 0.1820 - val_loss: 0.2409 - val_mean_absolute_error: 0.2409
# Epoch 4
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.1992 - mean_absolute_error: 0.1992 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459
# Epoch 5
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 3ms/step - loss: 0.2078 - mean_absolute_error: 0.2078 - val_loss: 0.2864 - val_mean_absolute_error: 0.2864
# Epoch 6
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 2s 2ms/step - loss: 0.2167 - mean_absolute_error: 0.2167 - val_loss: 0.2100 - val_mean_absolute_error: 0.2100
# Epoch 7
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 3s 4ms/step - loss: 0.2098 - mean_absolute_error: 0.2098 - val_loss: 0.2566 - val_mean_absolute_error: 0.2566
# Epoch 8
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 4ms/step - loss: 0.1723 - mean_absolute_error: 0.1723 - val_loss: 0.1613 - val_mean_absolute_error: 0.1613
# Epoch 9
# Train on 921 samples, validate on 103 samples
# Epoch 1/1
# 921/921 [==============================] - 4s 5ms/step - loss: 0.1398 - mean_absolute_error: 0.1398 - val_loss: 0.1390 - val_mean_absolute_error: 0.1390
